# %%
import pandas as pd

# %%
df = pd.read_csv("Amazon_popular_books_dataset.csv")

# %%
df
# Out:
#             asin         ISBN10  answered_questions availability  \
# 0     0007350813     0007350813                   0    In Stock.
# 1     0007513763  9780007513765                   0    In Stock.
# 2     0008183988     0008183988                   0          NaN
# 3     0008305838     0008305838                   0    In Stock.
# 4     0008375526     0008375526                   0    In Stock.
# ...          ...            ...                 ...          ...
# 2264  B07P5BPVGM            NaN                   0          NaN
# 2265  B07P5JBCFL            NaN                   0          NaN
# 2266  B07NF7DFS2            NaN                   0          NaN
# 2267  B07P67N918            NaN                   0          NaN
# 2268  B07PFY8K2N            NaN                   0          NaN
#
#                                                   brand currency  \
# 0                                          Emily Brontë      USD
# ...

# %%
#shape  df rows * cols

# %%
row,col = df.shape

# %%
row
# Out:
# 2269

# %%
col
# Out:
# 40

# %%
df.columns
# Out:
# Index(['asin', 'ISBN10', 'answered_questions', 'availability', 'brand',
#        'currency', 'date_first_available', 'delivery', 'department',
#        'description', 'discount', 'domain', 'features', 'final_price',
#        'format', 'image_url', 'images_count', 'initial_price', 'item_weight',
#        'manufacturer', 'model_number', 'plus_content', 'product_dimensions',
#        'rating', 'reviews_count', 'root_bs_rank', 'seller_id', 'seller_name',
#        'timestamp', 'title', 'upc', 'url', 'video', 'video_count',
#        'categories', 'best_sellers_rank', 'buybox_seller', 'image',
#        'number_of_sellers', 'colors'],
#       dtype='object')

# %%
df['asin']
# Out:
# 0       0007350813
# 1       0007513763
# 2       0008183988
# 3       0008305838
# 4       0008375526
#            ...
# 2264    B07P5BPVGM
# 2265    B07P5JBCFL
# 2266    B07NF7DFS2
# 2267    B07P67N918
# 2268    B07PFY8K2N
# Name: asin, Length: 2269, dtype: object

# %%
df = pd.DataFrame({'prdid by':[101,20,4056,656,6560],
                   'prdname':['test','copper','gold','silver','iron ore'],
                   'prdqnty':[343,643,4634,34,3435],
                   'prdprice':[64464,756564,345,6464,35435]
                   }
                  )

# %%
df1
# Out:
#    prdid by   prdname  prdqnty  prdprice
# 0       101      test      343     64464
# 1        20    copper      643    756564
# 2      4056      gold     4634       345
# 3       656    silver       34      6464
# 4      6560  iron ore     3435     35435

# %%
df1['prdid by']
# Out:
# 0     101
# 1      20
# 2    4056
# 3     656
# 4    6560
# Name: prdid by, dtype: int64

# %%
df1.prdid by
# Out:
#   Cell In[21], line 1
#     df1.prdid by
#               ^
# SyntaxError: invalid syntax

# %%
df1[['prdname','prdprice']]
# Out:
#     prdname  prdprice
# 0      test     64464
# 1    copper    756564
# 2      gold       345
# 3    silver      6464
# 4  iron ore     35435

# %%
df.columns
# Out:
# Index(['asin', 'ISBN10', 'answered_questions', 'availability', 'brand',
#        'currency', 'date_first_available', 'delivery', 'department',
#        'description', 'discount', 'domain', 'features', 'final_price',
#        'format', 'image_url', 'images_count', 'initial_price', 'item_weight',
#        'manufacturer', 'model_number', 'plus_content', 'product_dimensions',
#        'rating', 'reviews_count', 'root_bs_rank', 'seller_id', 'seller_name',
#        'timestamp', 'title', 'upc', 'url', 'video', 'video_count',
#        'categories', 'best_sellers_rank', 'buybox_seller', 'image',
#        'number_of_sellers', 'colors'],
#       dtype='object')

# %%
100 col -- 90   --  not in 10

100 col 10 except

# %%
not_required = ['image_url', 'images_count', 'initial_price', 'item_weight']

required_col = []

for col in df.columns:
    if col not in not_required:
        required_col.append(col)
print(required_col)
# Out:
# ['asin', 'ISBN10', 'answered_questions', 'availability', 'brand', 'currency', 'date_first_available', 'delivery', 'department', 'description', 'discount', 'domain', 'features', 'final_price', 'format', 'manufacturer', 'model_number', 'plus_content', 'product_dimensions', 'rating', 'reviews_count', 'root_bs_rank', 'seller_id', 'seller_name', 'timestamp', 'title', 'upc', 'url', 'video', 'video_count', 'categories', 'best_sellers_rank', 'buybox_seller', 'image', 'number_of_sellers', 'colors']

# %%
df[required_col]
# Out:
#             asin         ISBN10  answered_questions availability  \
# 0     0007350813     0007350813                   0    In Stock.
# 1     0007513763  9780007513765                   0    In Stock.
# 2     0008183988     0008183988                   0          NaN
# 3     0008305838     0008305838                   0    In Stock.
# 4     0008375526     0008375526                   0    In Stock.
# ...          ...            ...                 ...          ...
# 2264  B07P5BPVGM            NaN                   0          NaN
# 2265  B07P5JBCFL            NaN                   0          NaN
# 2266  B07NF7DFS2            NaN                   0          NaN
# 2267  B07P67N918            NaN                   0          NaN
# 2268  B07PFY8K2N            NaN                   0          NaN
#
#                                                   brand currency  \
# 0                                          Emily Brontë      USD
# ...

# %%
df.columns
# Out:
# Index(['asin', 'ISBN10', 'answered_questions', 'availability', 'brand',
#        'currency', 'date_first_available', 'delivery', 'department',
#        'description', 'discount', 'domain', 'features', 'final_price',
#        'format', 'image_url', 'images_count', 'initial_price', 'item_weight',
#        'manufacturer', 'model_number', 'plus_content', 'product_dimensions',
#        'rating', 'reviews_count', 'root_bs_rank', 'seller_id', 'seller_name',
#        'timestamp', 'title', 'upc', 'url', 'video', 'video_count',
#        'categories', 'best_sellers_rank', 'buybox_seller', 'image',
#        'number_of_sellers', 'colors'],
#       dtype='object')

# %%
required_col =[]

for col in df.columns:
    if col.startswith('d'):
        required_col.append(col)

# %%
required_col
# Out:
# ['date_first_available',
#  'delivery',
#  'department',
#  'description',
#  'discount',
#  'domain']

# %%
df[required_col]
# Out:
#      date_first_available                                           delivery  \
# 0                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 1                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 2                     NaN  ["FREE delivery January 4 - 10 if you spend $2...
# 3                     NaN  ["FREE delivery Tuesday, December 28 if you sp...
# 4                     NaN  ["FREE delivery Tuesday, December 28","Or fast...
# ...                   ...                                                ...
# 2264                  NaN                                                 []
# 2265                  NaN                                                 []
# 2266                  NaN                                                 []
# 2267                  NaN                                                 []
# 2268                  NaN                                                 []
#
# ...

# %%
df
# Out:
#             asin         ISBN10  answered_questions availability  \
# 0     0007350813     0007350813                   0    In Stock.
# 1     0007513763  9780007513765                   0    In Stock.
# 2     0008183988     0008183988                   0          NaN
# 3     0008305838     0008305838                   0    In Stock.
# 4     0008375526     0008375526                   0    In Stock.
# ...          ...            ...                 ...          ...
# 2264  B07P5BPVGM            NaN                   0          NaN
# 2265  B07P5JBCFL            NaN                   0          NaN
# 2266  B07NF7DFS2            NaN                   0          NaN
# 2267  B07P67N918            NaN                   0          NaN
# 2268  B07PFY8K2N            NaN                   0          NaN
#
#                                                   brand currency  \
# 0                                          Emily Brontë      USD
# ...

# %%
df1
# Out:
#    prdid by   prdname  prdqnty  prdprice
# 0       101      test      343     64464
# 1        20    copper      643    756564
# 2      4056      gold     4634       345
# 3       656    silver       34      6464
# 4      6560  iron ore     3435     35435

# %%
df1.dtypes
# Out:
# prdid by     int64
# prdname     object
# prdqnty      int64
# prdprice     int64
# dtype: object

# %%
python -- > str

Dataframe --> object

# %%
df1['prdprice_new'] = df1['prdprice']*10

# %%
df1
# Out:
#    prdid by   prdname  prdqnty  prdprice  prdprice_new
# 0       101      test      343     64464        644640
# 1        20    copper      643    756564       7565640
# 2      4056      gold     4634       345          3450
# 3       656    silver       34      6464         64640
# 4      6560  iron ore     3435     35435        354350

# %%
df1['test']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'test'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1['flag'] = 'true'

# %%
df1
# Out:
#    prdid by   prdname  prdqnty  prdprice  prdprice_new  flag
# 0       101      test      343     64464        644640  true
# 1        20    copper      643    756564       7565640  true
# 2      4056      gold     4634       345          3450  true
# 3       656    silver       34      6464         64640  true
# 4      6560  iron ore     3435     35435        354350  true

# %%
df1.dtypes
# Out:
# prdid by         int64
# prdname         object
# prdqnty          int64
# prdprice         int64
# prdprice_new     int64
# flag            object
# dtype: object

# %%
df1['prdqnty'] = df1['prdqnty'].astype('str')

# %%
df1.dtypes
# Out:
# prdid by         int64
# prdname         object
# prdqnty         object
# prdprice         int64
# prdprice_new     int64
# flag            object
# dtype: object

# %%
strcture -->

# %%
#delete col from DF

# %%
df1
# Out:
#    prdid by   prdname prdqnty  prdprice  prdprice_new  flag
# 0       101      test     343     64464        644640  true
# 1        20    copper     643    756564       7565640  true
# 2      4056      gold    4634       345          3450  true
# 3       656    silver      34      6464         64640  true
# 4      6560  iron ore    3435     35435        354350  true

# %%
df2 = df1.drop('prdname',axis=1)  # by default rows axis=0

# %%
df1
# Out:
#    prdid by   prdname prdqnty  prdprice  prdprice_new  flag
# 0       101      test     343     64464        644640  true
# 1        20    copper     643    756564       7565640  true
# 2      4056      gold    4634       345          3450  true
# 3       656    silver      34      6464         64640  true
# 4      6560  iron ore    3435     35435        354350  true

# %%
df2
# Out:
#    prdid by prdqnty  prdprice  prdprice_new  flag
# 0       101     343     64464        644640  true
# 1        20     643    756564       7565640  true
# 2      4056    4634       345          3450  true
# 3       656      34      6464         64640  true
# 4      6560    3435     35435        354350  true

# %%
df1.drop('prdname',axis=1,inplace=True)

# %%
df1
# Out:
#    prdid by prdqnty  prdprice  prdprice_new  flag
# 0       101     343     64464        644640  true
# 1        20     643    756564       7565640  true
# 2      4056    4634       345          3450  true
# 3       656      34      6464         64640  true
# 4      6560    3435     35435        354350  true

# %%
test = df1.drop('prdqnty',axis=1)

# %%
test
# Out:
#    prdid by  prdprice  prdprice_new  flag
# 0       101     64464        644640  true
# 1        20    756564       7565640  true
# 2      4056       345          3450  true
# 3       656      6464         64640  true
# 4      6560     35435        354350  true

# %%
df1.drop('prdqnty',axis=1,inplace=True)

# %%
df1
# Out:
#    prdid by  prdprice  prdprice_new  flag
# 0       101     64464        644640  true
# 1        20    756564       7565640  true
# 2      4056       345          3450  true
# 3       656      6464         64640  true
# 4      6560     35435        354350  true

# %%
df1.drop(columns=['prdid by','flag','prdprice'],axis=1,inplace=True)

# %%
df1
# Out:
#    prdprice_new
# 0        644640
# 1       7565640
# 2          3450
# 3         64640
# 4        354350

# %%
df1
# Out:
#    prdprice_new
# 0        644640
# 1       7565640
# 2          3450
# 3         64640
# 4        354350

# %%
df
# Out:
#    prdid by   prdname  prdqnty  prdprice
# 0       101      test      343     64464
# 1        20    copper      643    756564
# 2      4056      gold     4634       345
# 3       656    silver       34      6464
# 4      6560  iron ore     3435     35435

# %%
df.rename({'prdid by':'id','prdprice':'price'},axis=1,inplace=True)

# %%
df
# Out:
#      id   prdname  prdqnty   price
# 0   101      test      343   64464
# 1    20    copper      643  756564
# 2  4056      gold     4634     345
# 3   656    silver       34    6464
# 4  6560  iron ore     3435   35435

# %%
df.describe()
# Out:
#                 id      prdqnty          price
# count     5.000000     5.000000       5.000000
# mean   2278.600000  1817.800000  172654.400000
# std    2913.999966  2078.668492  327412.020908
# min      20.000000    34.000000     345.000000
# 25%     101.000000   343.000000    6464.000000
# 50%     656.000000   643.000000   35435.000000
# 75%    4056.000000  3435.000000   64464.000000
# max    6560.000000  4634.000000  756564.000000

# %%
df
# Out:
#      id   prdname  prdqnty   price
# 0   101      test      343   64464
# 1    20    copper      643  756564
# 2  4056      gold     4634     345
# 3   656    silver       34    6464
# 4  6560  iron ore     3435   35435

# %%
copper df3

gold df2

silver -- df1
